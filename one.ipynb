# %%
import pandas as pd

# %%
df=pd.read_csv('C:/Harshil/Data Science/End to end  Project/Energy_Demand/data/processed/featuredd_power_consumption.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245883 entries, 0 to 245882
# Data columns (total 22 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   Global_active_power               245883 non-null  float64
#  1   Global_reactive_power             245883 non-null  float64
#  2   Voltage                           245883 non-null  float64
#  3   Global_intensity                  245883 non-null  float64
#  4   Sub_metering_1                    245883 non-null  float64
#  5   Sub_metering_2                    245883 non-null  float64
#  6   Sub_metering_3                    245883 non-null  float64
#  7   Datetime                          245883 non-null  object
#  8   hour                              245883 non-null  int64
#  9   day                               245883 non-null  int64
#  10  month                             245883 non-null  int64
# ...

# %%
df.head()
# Out:
#    Global_active_power  Global_reactive_power  Voltage  Global_intensity  \
# 0                2.466                  0.000   241.09              10.2
# 1                2.590                  0.118   241.79              10.6
# 2                2.590                  0.132   242.04              10.6
# 3                2.576                  0.128   241.43              10.6
# 4                2.566                  0.128   241.05              10.6
#
#    Sub_metering_1  Sub_metering_2  Sub_metering_3             Datetime  hour  \
# 0             0.0             0.0             0.0  2007-01-01 01:00:00     1
# 1             0.0             0.0             0.0  2007-01-01 01:01:00     1
# 2             0.0             0.0             0.0  2007-01-01 01:02:00     1
# 3             0.0             0.0             0.0  2007-01-01 01:03:00     1
# 4             0.0             0.0             0.0  2007-01-01 01:04:00     1
#
# ...
